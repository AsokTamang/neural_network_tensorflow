# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import make_blobs

# %% [markdown]
# **Making dataset for training**

# %%
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
X_train, y_train = make_blobs(n_samples=2000, centers=centers, cluster_std=1.0,random_state=30)

# %% [markdown]
# **Training a softmax neural network model**

# %%
model = Sequential(
    [
        Dense(25,activation='relu'),
        Dense(15,activation='relu'),
        Dense(4,activation='softmax'),
    ]
)
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.001)
)
model.fit(X_train,y_train,epochs=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       1 model = Sequential(
#       2     [
#       3         Dense(25,activation='relu'),
#    (...)      6     ]
#       7 )
#       8 model.compile(
# ----> 9     loss=tf.keras.lossses.SparseCategoricalCrossentropy(),
#      10     optimizer=tf.keras.optimizers.Adam(0.001)
#      11 )
#      12 model.fit(X_train,y_train,epochs=10)
#
# AttributeError: module 'tensorflow.keras' has no attribute 'lossses'
